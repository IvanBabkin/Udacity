# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# ## Global Data

# %%
global_data = pd.read_csv('Global_Data.csv')
global_data.rename(columns={'year':'Year', 'avg_temp':'Global Average Temperature'}, inplace=True)
global_data.set_index('Year', inplace=True)
global_data
# Out:
#       Global Average Temperature
# Year
# 1750                        8.72
# 1751                        7.98
# 1752                        5.78
# 1753                        8.39
# 1754                        8.47
# ...                          ...
# 2011                        9.52
# 2012                        9.51
# 2013                        9.61
# 2014                        9.57
# 2015                        9.83
#
# [266 rows x 1 columns]

# %% [markdown]
# ## Edinburgh data

# %%
edinburgh_data = pd.read_csv('Edinburgh_Data.csv')
drop_columns = ['city', 'country']
edinburgh_data.drop(drop_columns, axis = 1, inplace=True)
edinburgh_data.rename(columns={'year':'Year', 'avg_temp':'Edinburgh Average Temperature'}, inplace=True)
edinburgh_data.set_index('Year', inplace=True)
edinburgh_data
# Out:
#       Edinburgh Average Temperature
# Year
# 1743                           5.27
# 1744                           8.29
# 1745                           2.75
# 1746                            NaN
# 1747                            NaN
# ...                             ...
# 2009                           8.64
# 2010                           7.43
# 2011                           8.95
# 2012                           8.08
# 2013                           8.39
#
# [271 rows x 1 columns]

# %% [markdown]
# ### Combining the two datasets

# %%
dataset = edinburgh_data.join(global_data, how="inner")
dataset
# Out:
#       Edinburgh Average Temperature  Global Average Temperature
# Year
# 1750                           8.41                        8.72
# 1751                           8.16                        7.98
# 1752                           4.78                        5.78
# 1753                           7.51                        8.39
# 1754                           7.42                        8.47
# ...                             ...                         ...
# 2009                           8.64                        9.51
# 2010                           7.43                        9.70
# 2011                           8.95                        9.52
# 2012                           8.08                        9.51
# 2013                           8.39                        9.61
#
# [264 rows x 2 columns]

# %%
print(dataset.loc[2000][0] == edinburgh_data.loc[2000])
print(dataset.loc[2000][1] == global_data.loc[2000])
# Out:
# Edinburgh Average Temperature    True
# Name: 2000, dtype: bool
# Global Average Temperature    True
# Name: 2000, dtype: bool

# %% [markdown]
# ### Creating a moving average dataset

# %%
moving_averages = pd.DataFrame()
moving_averages['Edinburgh'] = dataset['Edinburgh Average Temperature'].rolling(window=7).mean()
moving_averages['Global'] = dataset['Global Average Temperature'].rolling(window=7).mean()
moving_averages
# Out:
#       Edinburgh    Global
# Year
# 1750        NaN       NaN
# 1751        NaN       NaN
# 1752        NaN       NaN
# 1753        NaN       NaN
# 1754        NaN       NaN
# ...         ...       ...
# 2009   8.831429  9.535714
# 2010   8.614286  9.560000
# 2011   8.618571  9.588571
# 2012   8.508571  9.561429
# 2013   8.407143  9.572857
#
# [264 rows x 2 columns]

# %% [markdown]
# ### Plotting the results

# %%
moving_averages['Edinburgh'].plot(figsize = (15,8))
moving_averages['Global'].plot(figsize = (15,8))
plt.title('Line Chart of Global vs. Edinburgh Temperature (Moving Average)')
plt.ylabel('Temperature (ºC)')
plt.legend()
plt.show()

# %% [markdown]
# ### Correlation Coefficients

# %%
dataset.corr()
# Out:
#                                Edinburgh Average Temperature  \
# Edinburgh Average Temperature                       1.000000
# Global Average Temperature                          0.592681
#
#                                Global Average Temperature
# Edinburgh Average Temperature                    0.592681
# Global Average Temperature                       1.000000

# %% [markdown]
# ## Adding more cities

# %% [markdown]
# ## London data

# %%
london_data = pd.read_csv('London_Data.csv')
london_data.drop(drop_columns, axis = 1, inplace=True)
london_data.rename(columns={'year':'Year', 'avg_temp':'London Average Temperature'}, inplace=True)
london_data.set_index('Year', inplace=True)
london_data
# Out:
#       London Average Temperature
# Year
# 1743                        7.54
# 1744                       10.34
# 1745                        4.13
# 1746                         NaN
# 1747                         NaN
# ...                          ...
# 2009                       10.52
# 2010                        9.38
# 2011                       11.19
# 2012                       10.00
# 2013                        9.91
#
# [271 rows x 1 columns]

# %% [markdown]
# ## Cardiff data

# %%
cardiff_data = pd.read_csv('Cardiff_Data.csv')
cardiff_data.drop(drop_columns, axis = 1, inplace=True)
cardiff_data.rename(columns={'year':'Year', 'avg_temp':'Cardiff Average Temperature'}, inplace=True)
cardiff_data.set_index('Year', inplace=True)
cardiff_data
# Out:
#       Cardiff Average Temperature
# Year
# 1743                         7.07
# 1744                         9.80
# 1745                         4.05
# 1746                          NaN
# 1747                          NaN
# ...                           ...
# 2009                         9.90
# 2010                         8.80
# 2011                        10.63
# 2012                         9.55
# 2013                         9.57
#
# [271 rows x 1 columns]

# %% [markdown]
# ### Addding new cities to the dataset

# %%
dataset = london_data.join(dataset, how="inner")
dataset = cardiff_data.join(dataset, how="inner")
dataset
# Out:
#       Cardiff Average Temperature  London Average Temperature  \
# Year
# 1750                         9.73                       10.25
# 1751                         9.51                        9.99
# 1752                         6.26                        6.54
# 1753                         8.97                        9.42
# 1754                         8.82                        9.20
# ...                           ...                         ...
# 2009                         9.90                       10.52
# 2010                         8.80                        9.38
# 2011                        10.63                       11.19
# 2012                         9.55                       10.00
# 2013                         9.57                        9.91
#
#       Edinburgh Average Temperature  Global Average Temperature
# Year
# 1750                           8.41                        8.72
# 1751                           8.16                        7.98
# 1752                           4.78                        5.78
# 1753                           7.51                        8.39
# 1754                           7.42                        8.47
# ...                             ...                         ...
# 2009                           8.64                        9.51
# 2010                           7.43                        9.70
# 2011                           8.95                        9.52
# 2012                           8.08                        9.51
# 2013                           8.39                        9.61
#
# [264 rows x 4 columns]

# %%
moving_averages['London'] = dataset['London Average Temperature'].rolling(window=7).mean()
moving_averages['Cardiff'] = dataset['Cardiff Average Temperature'].rolling(window=7).mean()
moving_averages
# Out:
#       Edinburgh    Global     London    Cardiff
# Year
# 1750        NaN       NaN        NaN        NaN
# 1751        NaN       NaN        NaN        NaN
# 1752        NaN       NaN        NaN        NaN
# 1753        NaN       NaN        NaN        NaN
# 1754        NaN       NaN        NaN        NaN
# ...         ...       ...        ...        ...
# 2009   8.831429  9.535714  10.720000  10.204286
# 2010   8.614286  9.560000  10.515714   9.997143
# 2011   8.618571  9.588571  10.575714  10.048571
# 2012   8.508571  9.561429  10.485714   9.950000
# 2013   8.407143  9.572857  10.315714   9.805714
#
# [264 rows x 4 columns]

# %% [markdown]
# ### Ploting the results for 4 cities

# %%
moving_averages['Edinburgh'].plot(figsize = (15,8))
moving_averages['London'].plot(figsize = (15,8))
moving_averages['Cardiff'].plot(figsize = (15,8))
moving_averages['Global'].plot(figsize = (15,8))
plt.title('Line Chart of Moving Average Temperature')
plt.ylabel('Temperature (ºC)')
plt.legend()
plt.show()

# %% [markdown]
# ### Correlation Coefficients

# %%
dataset.corr()
# Out:
#                                Cardiff Average Temperature  \
# Cardiff Average Temperature                       1.000000
# London Average Temperature                        0.991755
# Edinburgh Average Temperature                     0.969152
# Global Average Temperature                        0.588579
#
#                                London Average Temperature  \
# Cardiff Average Temperature                      0.991755
# London Average Temperature                       1.000000
# Edinburgh Average Temperature                    0.950873
# Global Average Temperature                       0.563099
#
#                                Edinburgh Average Temperature  \
# Cardiff Average Temperature                         0.969152
# London Average Temperature                          0.950873
# Edinburgh Average Temperature                       1.000000
# Global Average Temperature                          0.592681
#
#                                Global Average Temperature
# Cardiff Average Temperature                      0.588579
# London Average Temperature                       0.563099
# Edinburgh Average Temperature                    0.592681
# Global Average Temperature                       1.000000

# %%
sn.heatmap(dataset.corr(), annot=True)
plt.show()
